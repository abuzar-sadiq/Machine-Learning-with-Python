# %% [markdown]
# # Linear Regression
# y=mx+c is slope of the line
# y=b0+b1*X1
# salary=b0+b1*Experience
# c=b0
# m=b1

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Salary_Data.csv')

# %%
dataset.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
X = dataset.iloc[:,:-2].values
Y = dataset.iloc[:,2:].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
Y_test
# Out:
# array([[ 37731],
#        [122391],
#        [ 57081],
#        [ 63218],
#        [116969],
#        [109431],
#        [112635],
#        [ 55794],
#        [ 83088]], dtype=int64)

# %%
plt.scatter(X,Y)

# %% [markdown]
# To check which model is perfect (linear model is good)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor= LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = regressor.predict(X_test)

# %%
Y_test,Y_pred
# Out:
# (array([[ 37731],
#         [122391],
#         [ 57081],
#         [ 63218],
#         [116969],
#         [109431],
#         [112635],
#         [ 55794],
#         [ 83088]], dtype=int64),
#  array([[ 40817.78327049],
#         [123188.08258899],
#         [ 65154.46261459],
#         [ 63282.41035735],
#         [115699.87356004],
#         [108211.66453108],
#         [116635.89968866],
#         [ 64218.43648597],
#         [ 76386.77615802]]))

# %%
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('Salary vs Experience')
plt.xlabel('years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('Salary vs Experience')
plt.xlabel('years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
# if Year of experience of employee is 12

# %%
print(regressor.predict([[12]]))
# Out:
# [[139100.52677552]]

# %%
c = regressor.intercept_
m = regressor.coef_

# %%
c,m
# Out:
# (array([26777.3913412]), array([[9360.26128619]]))

# %% [markdown]
# salary = 9360*years of experience + 26777
